# %%
from nltk.tokenize import RegexpTokenizer 
from nltk.corpus import stopwords
#https://www.opentaal.org/bestanden/file/2-woordenlijst-v-2-10g-bronbestanden
#https://creativecommons.org/licenses/by/3.0/legalcode
tokenizer = RegexpTokenizer(r'\w+')
corpus = tokenizer.tokenize((open('db/OpenTaal-210G-basis-gekeurd.txt').read().lower()))

#for now we only use the alphabetical characters
import re
corpus = [word for word in corpus if [word] == re.findall(r"[a-z]+",word)]

# %%
#class based on https://twitter.com/fermatslibrary/status/958700402647674880
class Anagrammer:
    alphabet = {"a":2,"b":3,"c":5,"d":7,"e":11,"f":13,"g":17,"h":19,"i":23,"j":29,"k":31,"l":37,"m":41,"n":43,"o":47,"p":53,"q":59,"r":61,"s":67,"t":71,"u":73,"v":79,"w":83,"x":89,"y":97,"z":101}

    def __init__(self, corpus):
        self.index = {}
        self.createIndex(corpus)
    
    def createAnagramIndexNumber(self, word):
        index = 1
        for x in list(word):
            index *= self.alphabet[x]
        return index

    def createIndex(self, corpus):
        for word in corpus:
            self.index.setdefault(self.createAnagramIndexNumber(word),set())
            self.index[self.createAnagramIndexNumber(word)].add(word);
    
    def getAnagrams(self, word):
        return self.index[self.createAnagramIndex(word)]

# %%
ana = Anagrammer(corpus)

# %%
for word in set(corpus):
    if len(ana.getAnagrams(word)) > 1:
        print ana.getAnagrams(word)
# Out:
# set(['kartelen', 'nekartel', 'rekenlat', 'klateren'])
# set(['rampvlucht', 'palmvrucht'])
# set(['spoorwagen', 'wagenspoor'])
# set(['tijdverlies', 'verliestijd'])
# set(['schemeravond', 'avondschemer'])
# set(['orangist', 'organist'])
# set(['ernst', 'stern', 'trens', 'nerts', 'snert'])
# set(['and', 'nda', 'dan', 'dna'])
# set(['ezelskop', 'zoekspel'])
# set(['antiek', 'intake'])
# set(['verdoen', 'onvrede'])
# set(['toef', 'ofte'])
# set(['koffiemok', 'koffiekom'])
# set(['caisson', 'incasso'])
# set(['vergasten', 'vragenset'])
# set(['mannenmode', 'mannenmoed'])
# set(['dragline', 'landerig'])
# set(['gif', 'fig'])
# set(['fik', 'kif'])
# set(['hulpproject', 'projecthulp'])
# set(['kunstwoord', 'woordkunst'])
# set(['vrijheidsbeweging', 'bewegingsvrijheid'])
# set(['bustaxi', 'taxibus'])
# set(['marktgeld', 'geldmarkt'])
# set(['uitbomen', 'buitenom'])
# set(['these', 'sheet'])
# set(['protserig', 'stroperig'])
# set(['breed', 'berde'])
# set(['masten', 'matsen'])
# set(['vloertegel', 'tegelvloer'])
# set(['kraaknet', 'katanker', 'kerntaak'])
# set(['tering', 'ginter'])
# set(['glarieogen', 'algengroei'])
# set(['hymne', 'hymen'])
# set(['modelstudie', 'studiemodel'])
# set(['afzetnet', 'afzetten'])
# set(['venen', 'neven'])
# set(['inzage', 'geniza'])
# set(['pacht', 'patch'])
# set(['stoorniveau', 'soortniveau'])
# set(['grunge', 'ruggen'])
# set(['zatladder', 'ladderzat'])
# set(['alto', 'lota', 'atol'])
# set(['gebruiken', 'bekeuring', 'negebruik'])
# set(['veldproef', 'proefveld'])
# set(['afroep', 'eropaf'])
# set(['skaten', 'staken', 'kasten'])
# set(['esdoren', 'doseren'])
# set(['tips', 'stip', 'spit'])
# set(['onverdacht', 'ondervacht'])
# set(['spie', 'peis', 'pies'])
# set(['snip', 'spin'])
# set(['pils', 'spil', 'slip'])
# set(['kerndoel', 'kolderen'])
# set(['afketsen', 'afsteken'])
# set(['elders', 'selder'])
# set(['strek', 'kerst', 'sterk'])
# set(['kunstfoto', 'fotokunst'])
# set(['knobbeljicht', 'jichtknobbel'])
# set(['winterdek', 'kinderwet'])
# set(['gemeentewerk', 'werkgemeente'])
# set(['volzin', 'zinvol'])
# set(['paren', 'rapen'])
# set(['gireren', 'griener'])
# set(['singulier', 'sluiering'])
# set(['waterleven', 'waternevel'])
# set(['bolderen', 'belronde'])
# set(['lenteroos', 'netelroos', 'renteloos'])
# set(['pover', 'prove'])
# set(['notuliste', 'tuinstoel'])
# set(['oogje', 'joego'])
# set(['macht', 'match'])
# set(['muiten', 'minute'])
# set(['raketsla', 'leskaart'])
# set(['handenwerk', 'werkhanden', 'handwerken'])
# set(['eremetaal', 'eermetaal'])
# set(['penoze', 'poezen'])
# set(['lenig', 'inleg'])
# set(['maarts', 'matras'])
# set(['beeldschrift', 'schriftbeeld'])
# set(['wingerd', 'dwinger'])
# set(['negrito', 'gierton'])
# set(['damestrio', 'radiostem'])
# set(['zandvorm', 'vormzand'])
# set(['montage', 'megaton'])
# set(['rechtop', 'oprecht'])
# set(['belial', 'labiel'])
# set(['lijstgevel', 'gevellijst'])
# set(['garneren', 'rangeren'])
# set(['jid', 'dij'])
# set(['leut', 'tule'])
# set(['buiswater', 'waterbuis'])
# set(['pij', 'jip'])
# set(['ministre', 'minister', 'terminis'])
# set(['aslade', 'salade'])
# set(['zeiker', 'keizer', 'kiezer'])
# set(['sportraad', 'radarpost'])
# set(['hamer', 'harem'])
# set(['gedrein', 'nederig', 'dreigen', 'driegen'])
# set(['dagwinkel', 'winkeldag'])
# set(['kapitaalreserve', 'reservekapitaal'])
# set(['turner', 'return'])
# set(['afploegen', 'afgelopen'])
# set(['kleien', 'kielen', 'kleine', 'keilen'])
# set(['nvloeding', 'vondeling'])
# set(['kween', 'weken'])
# set(['beverleiding', 'gildebrieven'])
# set(['belangen', 'langbeen'])
# set(['tenthuis', 'thuisnet'])
# set(['schilderkunst', 'kunstschilder'])
# set(['knakker', 'krakken'])
# set(['vlagsignaal', 'signaalvlag'])
# set(['reerd', 'erder', 'reder'])
# set(['neder', 'deren', 'deern', 'erden', 'reden', 'neerd'])
# set(['recordjaar', 'jaarrecord'])
# set(['potas', 'topas', 'aspot'])
# set(['single', 'singel'])
# set(['perron', 'porren'])
# set(['zeulen', 'leuzen'])
# set(['molensteen', 'steenmolen'])
# set(['bijvorm', 'bomvrij'])
# set(['blauwvos', 'vlasbouw'])
# set(['pteren', 'penter'])
# set(['filmsucces', 'succesfilm'])
# set(['europese', 'europees'])
# set(['traag', 'grata', 'graat'])
# set(['booreiland', 'loonarbeid'])
# set(['graad', 'gaard'])
# set(['sleets', 'steels'])
# set(['puntverlies', 'verliespunt'])
# set(['sealen', 'leasen'])
# set(['relevatie', 'revelatie'])
# set(['zorgpremie', 'zomergriep'])
# set(['gaar', 'raga'])
# set(['polynoom', 'monopoly'])
# set(['serviel', 'verlies'])
# set(['vlotheid', 'vilthoed'])
# set(['trips', 'strip'])
# set(['stilaan', 'analist', 'natalis'])
# set(['sterken', 'streken'])
# set(['opperen', 'propeen'])
# set(['frutsel', 'slufter'])
# set(['stilaan', 'analist', 'natalis'])
# set(['lichtglans', 'lichtslang'])
# set(['riedel', 'leider', 'erelid'])
# set(['nors', 'snor'])
# set(['opnamedag', 'dagopname'])
# set(['eigendom', 'moedigen'])
# set(['koffieochtend', 'ochtendkoffie'])
# set(['perfectie', 'receptief'])
# set(['klieren', 'krielen'])
# set(['leis', 'lies'])
# set(['leden', 'delen', 'lende'])
# set(['bouwbeurs', 'busbouwer'])
# set(['vetpuist', 'vetspuit'])
# set(['sjah', 'hasj'])
# set(['latwerk', 'kwartel'])
# set(['wandelgang', 'dwangnagel'])
# set(['ploegwerk', 'werkploeg', 'oplegwerk'])
# set(['oreren', 'roeren'])
# set(['mora', 'roma'])
# set(['erom', 'more', 'rome', 'roem', 'moer'])
# set(['grijpen', 'rijgpen'])
# set(['wieder', 'weider', 'wierde'])
# set(['borden', 'bonder', 'borend'])
# set(['theems', 'heemst'])
# set(['paper', 'rappe'])
# set(['verbieden', 'bedierven', 'verbeiden'])
# set(['gerieven', 'gevieren'])
# set(['shocking', 'schonkig'])
# set(['veerring', 'verering'])
# set(['stroomimport', 'importstroom'])
# set(['samisch', 'schisma'])
# set(['draadeind', 'inderdaad'])
# set(['machteloos', 'schoolteam'])
# set(['mastel', 'smalte'])
# set(['taxipost', 'taxistop'])
# set(['bisam', 'bamis'])
# set(['begraving', 'bevraging'])
# set(['aalscholver', 'schollevaar'])
# set(['krek', 'kerk'])
# set(['beddentijk', 'bedenktijd'])
# set(['landwet', 'wetland'])
# set(['stafkaart', 'taakstraf'])
# set(['kanten', 'tanken'])
# set(['belastingvoorstel', 'betalingsvoorstel'])
# set(['tirade', 'triade'])
# set(['spierbuik', 'buikspier'])
# set(['hartcentrum', 'returnmatch'])
# set(['tiara', 'tiaar'])
# set(['striae', 'satire'])
# set(['smeten', 'entmes', 'mesten', 'metsen'])
# set(['praatje', 'paartje', 'apartje'])
# set(['breed', 'berde'])
# set(['blauwvos', 'vlasbouw'])
# set(['bandstoot', 'stootband'])
# set(['presens', 'pressen'])
# set(['hoekhuis', 'huishoek'])
# set(['zepen', 'pezen'])
# set(['grafkamer', 'grafmaker'])
# set(['rookspek', 'kroeskop'])
# set(['kno', 'nok', 'kon'])
# set(['betel', 'belet'])
# set(['gebel', 'beleg'])
# set(['grasbuik', 'gruisbak'])
# set(['keurling', 'kleuring'])
# set(['maats', 'astma'])
# set(['ressource', 'resources'])
# set(['gerand', 'grande', 'dragen', 'gander'])
# set(['buitenspel', 'builenpest'])
# set(['hoesfoto', 'theosoof'])
# set(['landwijn', 'wijnland'])
# set(['laatje', 'aaltje'])
# set(['lus', 'sul'])
# set(['saam', 'maas'])
# set(['levenskunstenaar', 'kunstenaarsleven'])
# set(['single', 'singel'])
# set(['redenering', 'denigreren'])
# set(['verleiden', 'dierenvel'])
# set(['siersteen', 'interesse'])
# set(['bedroevend', 'eedverbond'])
# set(['ritenuto', 'uiterton'])
# set(['sandaal', 'lasnaad'])
# set(['maken', 'kamen'])
# set(['kamer', 'maker'])
# set(['klavieren', 'valkenier'])
# set(['pantserglas', 'grensplaats'])
# set(['bankdeposito', 'depositobank'])
# set(['bomvrouw', 'bouwvorm'])
# set(['duren', 'dreun'])
# set(['oliestad', 'diastole'])
# set(['vinkje', 'kijven'])
# set(['rode', 'orde', 'oder'])
# set(['borstelen', 'bolsteren'])
# set(['printmedia', 'maidentrip'])
# set(['achterstal', 'achterlast', 'rechtstaal'])
# set(['maal', 'lama', 'alma'])
# set(['partnertoeslag', 'toeslagpartner'])
# set(['contractwerk', 'werkcontract'])
# set(['nvloeding', 'vondeling'])
# set(['tsaar', 'staar', 'rasta'])
# set(['atlas', 'staal'])
# set(['naast', 'staan', 'satan'])
# set(['staag', 'asgat'])
# set(['nipt', 'pint'])
# set(['pistool', 'pitloos'])
# set(['lener', 'leren', 'nleer'])
# set(['kamerkoor', 'rookkamer'])
# set(['verzien', 'vriezen', 'veinzer'])
# set(['recepis', 'precies'])
# set(['vormtaal', 'taalvorm'])
# set(['lidwoord', 'roodwild'])
# set(['massageolie', 'oliemassage'])
# set(['slagwerk', 'glaswerk'])
# set(['berm', 'brem'])
# set(['brie', 'brei', 'bier'])
# set(['reinette', 'eterniet', 'retentie'])
# set(['gietmal', 'metalig'])
# set(['consumptiemelk', 'melkconsumptie'])
# set(['boelijn', 'biljoen'])
# set(['skiteam', 'mastiek'])
# set(['slagarm', 'armslag'])
# set(['kinderkost', 'stikdonker'])
# set(['belast', 'asbelt'])
# set(['avondconcert', 'concertavond'])
# set(['omspelen', 'omslepen'])
# set(['bankkennis', 'kennisbank'])
# set(['bierkan', 'bankier'])
# set(['vakantiebeurs', 'beursvakantie'])
# set(['breeduit', 'debiteur'])
# set(['vloerplanken', 'plankenvloer'])
# set(['reine', 'reien'])
# set(['trachoom', 'chatroom'])
# set(['ervandaan', 'aandraven'])
# set(['rijkleed', 'deerlijk', 'redelijk', 'lijkrede'])
# set(['postament', 'mastentop'])
# set(['beenmerg', 'mergbeen'])
# set(['gebouwd', 'boudweg'])
# set(['wasbeits', 'basiswet'])
# set(['verkondigen', 'overdenking'])
# set(['stagneren', 'transgeen'])
# set(['lebberen', 'rebbelen'])
# set(['bevrijdster', 'verbijsterd'])
# set(['stijlvast', 'slijtvast'])
# set(['boekgeschenk', 'geschenkboek'])
# set(['vederbal', 'bladveer'])
# set(['belastinginkomsten', 'inkomstenbelasting'])
# set(['koffiepoeder', 'poederkoffie'])
# set(['soapster', 'pastores'])
# set(['heraanleg', 'hengelaar'])
# set(['gebroddel', 'drogbeeld'])
# set(['roeier', 'roerei'])
# set(['voorbereidingsgesprek', 'gespreksvoorbereiding'])
# set(['vierendeel', 'veerlieden'])
# set(['terzet', 'zetter'])
# set(['stadslijn', 'dansstijl', 'stijldans'])
# set(['pluimriet', 'rietpluim'])
# set(['saksen', 'kassen'])
# set(['golven', 'volgen', 'vlogen'])
# set(['lijnvlucht', 'vluchtlijn'])
# set(['koffiemok', 'koffiekom'])
# set(['razend', 'zander'])
# set(['menage', 'manege'])
# set(['besturing', 'berusting'])
# set(['kunstroof', 'roofkunst'])
# set(['ert', 'ter', 'tre'])
# set(['res', 'ser', 'ers'])
# set(['erd', 'der', 'red'])
# set(['ere', 'ree', 'eer'])
# set(['are', 'era'])
# set(['mager', 'gamer', 'geram', 'marge'])
# set(['zeisen', 'seizen'])
# set(['stierf', 'frites', 'friste'])
# set(['huisraad', 'raadhuis'])
# set(['berkenolie', 'boerenkiel'])
# set(['afsturen', 'aftersun'])
# set(['beklant', 'blanket'])
# set(['onderploegen', 'ondergelopen'])
# set(['hockeyveld', 'veldhockey'])
# set(['doelworp', 'werplood'])
# set(['topo', 'poot'])
# set(['opkopen', 'oppoken'])
# set(['incrementele', 'incrementeel'])
# set(['koperrood', 'kooporder', 'roodkoper'])
# set(['nultolerantie', 'antillenroute'])
# set(['loopwedstrijd', 'wedstrijdloop'])
# set(['merinos', 'romeins'])
# set(['inmaak', 'maniak'])
# set(['appelgroen', 'galopperen'])
# set(['turbodiesel', 'uitbroedsel'])
# set(['verkeersader', 'reservekader'])
# set(['goed', 'doge', 'doeg'])
# set(['turner', 'return'])
# set(['kinderzaal', 'klaarziend'])
# set(['speelverbod', 'beroepsveld'])
# set(['uitloodsen', 'loonstudie', 'studieloon'])
# set(['lichtflits', 'flitslicht'])
# set(['revanchist', 'vriesnacht'])
# set(['rune', 'urne', 'uren'])
# set(['wiel', 'weil'])
# set(['verdelging', 'vergelding'])
# set(['pastel', 'spatel', 'slapte', 'stapel', 'telpas'])
# set(['pastei', 'spatie'])
# set(['leasemarkt', 'lemsteraak'])
# set(['vermaner', 'verarmen'])
# set(['droomplek', 'moordplek'])
# set(['slijten', 'stijlen', 'lijsten'])
# set(['parisien', 'aspirine'])
# set(['stakker', 'kakster', 'trekkas'])
# set(['stierennek', 'erkentenis'])
# set(['naamdag', 'maandag'])
# set(['tarwe', 'water'])
# set(['berenvel', 'bevernel'])
# set(['doorgronden', 'doordrongen'])
# set(['veelal', 'alevel'])
# set(['username', 'amuseren'])
# set(['ondervraging', 'ondergraving'])
# set(['fust', 'stuf'])
# set(['financieringsbedrijf', 'bedrijfsfinanciering'])
# set(['beeldarchief', 'archiefbeeld'])
# set(['uilskop', 'luiskop'])
# set(['stroopkan', 'kanosport'])
# set(['gezel', 'zegel'])
# set(['reisbus', 'busreis'])
# set(['klapbaar', 'krabpaal'])
# set(['reuzin', 'ruizen'])
# set(['creativiteit', 'reactiviteit'])
# set(['assimileren', 'islamiseren'])
# set(['poseren', 'snoeper'])
# set(['biksteen', 'bekisten'])
# set(['schepijs', 'ijsschep'])
# set(['potbloem', 'bloempot'])
# set(['labeling', 'ballinge'])
# set(['verso', 'servo'])
# set(['moeiteloos', 'emotieloos'])
# set(['duinvoet', 'uitdoven', 'tienvoud'])
# set(['huisverkoop', 'verkoophuis'])
# set(['kunstlied', 'liedkunst'])
# set(['test', 'tets'])
# set(['koortsvrij', 'voorstrijk'])
# set(['staartklok', 'straatkolk'])
# set(['kegelas', 'askegel'])
# set(['battle', 'tablet'])
# set(['ntaal', 'alant'])
# set(['pantserglas', 'grensplaats'])
# set(['marktniche', 'nichemarkt'])
# set(['regel', 'leger'])
# set(['genre', 'geren', 'green', 'regen', 'neger'])
# set(['orkest', 'stoker', 'trekos', 'koster', 'korset'])
# set(['autostop', 'postauto'])
# set(['welken', 'kwelen'])
# set(['strofe', 'stroef'])
# set(['uitbomen', 'buitenom'])
# set(['inch', 'chin'])
# set(['vlieten', 'ventiel'])
# set(['rafter', 'frater'])
# set(['steenstort', 'stortsteen'])
# set(['puibalk', 'buiklap'])
# set(['blusser', 'brussel'])
# set(['kade', 'adek'])
# set(['fietsvakantie', 'vakantiefiets'])
# set(['mbo', 'bom'])
# set(['gelasten', 'lengteas', 'galsteen'])
# set(['meikrans', 'nakermis'])
# set(['drop', 'dorp'])
# set(['stadsregering', 'regeringsstad'])
# set(['lord', 'drol'])
# set(['denkwijze', 'dijkwezen'])
# set(['hymne', 'hymen'])
# set(['relevatie', 'revelatie'])
# set(['rekentuig', 'kneuterig'])
# set(['kredietbank', 'bankkrediet'])
# set(['bontlaars', 'staalbron'])
# set(['verwesteren', 'weerstreven'])
# set(['verzoener', 'roerzeven'])
# set(['vaalgroen', 'volgaarne'])
# set(['levenslang', 'slangenvel'])
# set(['bommelder', 'belommerd'])
# set(['elpen', 'pelen'])
# set(['nootmuskaat', 'muskaatnoot'])
# set(['etalagist', 'gietstaal'])
# set(['zonde', 'zoden'])
# set(['godsrijk', 'gorsdijk'])
# set(['topgevel', 'geveltop'])
# set(['loket', 'klote', 'kloet'])
# set(['walvisbaard', 'baardwalvis'])
# set(['subvragen', 'vragenbus'])
# set(['voer', 'over', 'vore'])
# set(['staatsmacht', 'machtsstaat'])
# set(['tonner', 'tornen', 'tronen'])
# set(['celibatair', 'calibratie'])
# set(['poeh', 'hoep', 'hope'])
# set(['verzien', 'vriezen', 'veinzer'])
# set(['wegvoering', 'overweging'])
# set(['deelproject', 'projectdeel'])
# set(['spelcomputer', 'computerspel'])
# set(['larve', 'alver'])
# set(['paltsgraaf', 'grafplaats'])
# set(['bedreiger', 'bedrieger'])
# set(['bedriegen', 'bedreigen'])
# set(['eekhoorn', 'koehoren'])
# set(['spanader', 'spaander'])
# set(['pester', 'streep'])
# set(['afroep', 'eropaf'])
# set(['petsen', 'speten', 'pesten'])
# set(['lodder', 'roddel'])
# set(['voerkosten', 'voortekens', 'voorsteken'])
# set(['briefmodel', 'modelbrief'])
# set(['alarmreset', 'martelares'])
# set(['neon', 'none', 'onne', 'noen'])
# set(['selectiewedstrijd', 'wedstrijdselectie'])
# set(['fakir', 'kafir'])
# set(['kleien', 'kielen', 'kleine', 'keilen'])
# set(['dorsten', 'storend', 'onderst'])
# set(['drama', 'damar'])
# set(['werkpak', 'pakwerk'])
# set(['blozen', 'benzol'])
# set(['rechtsvordering', 'vorderingsrecht'])
# set(['modelactie', 'actiemodel'])
# set(['vulgaat', 'vulgata'])
# set(['topo', 'poot'])
# set(['voetbalprof', 'profvoetbal'])
# set(['pook', 'koop'])
# set(['polo', 'loop', 'pool'])
# set(['laaien', 'alinea'])
# set(['meeladen', 'deelname'])
# set(['apartheid', 'hitparade'])
# set(['drukletter', 'letterdruk'])
# set(['verrekt', 'vertrek'])
# set(['vervalsen', 'verslaven'])
# set(['leuningstoel', 'stoelleuning'])
# set(['omscholing', 'mongolisch'])
# set(['uitgeven', 'uitvegen'])
# set(['bereids', 'bereisd'])
# set(['veerpont', 'opvreten', 'verpoten', 'pontveer'])
# set(['atlete', 'atleet'])
# set(['stijladvies', 'adviesstijl', 'advieslijst'])
# set(['knipsel', 'kniples'])
# set(['tariefzone', 'zonetarief'])
# set(['wonderland', 'ronddwalen'])
# set(['orderstroom', 'doorstromer'])
# set(['doorstromen', 'onderstroom'])
# set(['spoorfiets', 'sproeistof'])
# set(['klephoorn', 'honkloper'])
# set(['orkest', 'stoker', 'trekos', 'koster', 'korset'])
# set(['toverkring', 'verkorting'])
# set(['stopkraan', 'ponskaart'])
# set(['diamantindustrie', 'industriediamant'])
# set(['ponsen', 'nopens'])
# set(['pierrot', 'portier'])
# set(['onderkotsen', 'stedenkroon'])
# set(['lord', 'drol'])
# set(['pacteren', 'capteren'])
# set(['aarsvin', 'varinas'])
# set(['lekwater', 'waterlek'])
# set(['managementprogramma', 'programmamanagement'])
# set(['daarboven', 'braadoven'])
# set(['uitkijk', 'kijkuit'])
# set(['spellingfout', 'foutspelling'])
# set(['roodzijden', 'noordzijde'])
# set(['loonstandaard', 'standaardloon'])
# set(['onbewust', 'nestbouw'])
# set(['reekszege', 'zegereeks'])
# set(['overijlen', 'oeverlijn'])
# set(['filmrol', 'rolfilm'])
# set(['xix', 'xxi'])
# set(['stagedag', 'gestaagd'])
# set(['banvloeken', 'bovenlaken'])
# set(['lastgeving', 'vliegangst', 'vlaggenist', 'vastliggen'])
# set(['gassector', 'escargots'])
# set(['enharmonisch', 'harmonischen'])
# set(['dakleer', 'kardeel'])
# set(['traag', 'grata', 'graat'])
# set(['verdelgen', 'vergelden', 'verlengde'])
# set(['verdelger', 'vergelder'])
# set(['prutsen', 'spurten'])
# set(['kalen', 'laken'])
# set(['gambiet', 'megabit'])
# set(['spurter', 'prutser'])
# set(['afdrogen', 'afgerond'])
# set(['struif', 'fruits'])
# set(['sileen', 'liseen', 'silene', 'seniel'])
# set(['megaster', 'gasmeter'])
# set(['verzoenend', 'overzenden'])
# set(['schetsontwerp', 'ontwerpschets'])
# set(['albatros', 'strobaal'])
# set(['ervandaan', 'aandraven'])
# set(['grand', 'drang'])
# set(['teloh', 'hotel', 'holte'])
# set(['achtervering', 'verachtering'])
# set(['recreatiewater', 'waterrecreatie'])
# set(['bureauhoofd', 'hoofdbureau'])
# set(['maatglas', 'maatslag', 'gastmaal', 'laagstam'])
# set(['ketenzorg', 'zorgketen'])
# set(['studieplan', 'planstudie'])
# set(['zeekrab', 'zeebrak'])
# set(['hamerteen', 'herenteam'])
# set(['simmen', 'immens'])
# set(['noodnet', 'ontdoen'])
# set(['sabra', 'brasa', 'baars'])
# set(['bedelven', 'bevelend', 'beneveld'])
# set(['kooksel', 'kookles'])
# set(['eivol', 'vloei', 'voile'])
# set(['participatiecultuur', 'cultuurparticipatie'])
# set(['oliepit', 'politie'])
# set(['spoornet', 'proosten'])
# set(['boomstam', 'stamboom', 'mastboom'])
# set(['eindejaar', 'jaareinde'])
# set(['dranger', 'redrang'])
# set(['aansteken', 'tenenkaas'])
# set(['tekenblad', 'kantelbed'])
# set(['beeldpunt', 'tulpenbed'])
# set(['zakpijp', 'pijpzak'])
# set(['tenware', 'wateren'])
# set(['ringkade', 'kadering'])
# set(['ijlden', 'lijden'])
# set(['damestrio', 'radiostem'])
# set(['portugese', 'portugees'])
# set(['schokeffect', 'shockeffect'])
# set(['kostendruk', 'drukkosten'])
# set(['neevraag', 'aangever'])
# set(['raat', 'rata'])
# set(['halsring', 'ringhals'])
# set(['rota', 'rato'])
# set(['biertent', 'bitteren'])
# set(['meet', 'teem'])
# set(['aflakken', 'afkalken'])
# set(['stroomnet', 'netstroom'])
# set(['achterstal', 'achterlast', 'rechtstaal'])
# set(['vliegkunst', 'kunstvlieg'])
# set(['ketenproces', 'procesketen'])
# set(['pronkkast', 'tankkorps'])
# set(['overlast', 'stalvoer'])
# set(['zuidtak', 'zakduit'])
# set(['bermgras', 'grasberm'])
# set(['afspelen', 'afslepen'])
# set(['papierslag', 'glaspapier'])
# set(['mijt', 'tijm'])
# set(['uitrusten', 'uitsturen'])
# set(['boekverkoop', 'verkoopboek'])
# set(['geeloranje', 'oranjegeel'])
# set(['ritme', 'mirte', 'timer'])
# set(['leengoed', 'ongeleed'])
# set(['stopdatum', 'postdatum'])
# set(['codelijst', 'decostijl'])
# set(['versieren', 'reviseren'])
# set(['taurine', 'uraniet'])
# set(['dino', 'indo'])
# set(['bedreven', 'bederven'])
# set(['wol', 'low'])
# set(['monopolie', 'omplooien'])
# set(['orni', 'noir', 'iron'])
# set(['kervel', 'klever', 'krevel'])
# set(['zomerfestival', 'festivalzomer'])
# set(['vaarskalf', 'kalfvaars'])
# set(['eik', 'kei'])
# set(['gek', 'keg'])
# set(['erwten', 'tweern'])
# set(['toverkring', 'verkorting'])
# set(['spankeren', 'naspreken'])
# set(['rondo', 'donor', 'doorn', 'noord'])
# set(['beltegoed', 'boetegeld', 'geldboete'])
# set(['postbedrijf', 'bedrijfstop'])
# set(['looptest', 'testloop'])
# set(['leken', 'kelen', 'enkel'])
# set(['dribbel', 'bebrild'])
# set(['uitvagen', 'uitgaven'])
# set(['hiermede', 'meerheid'])
# set(['tetra', 'tater'])
# set(['meten', 'meent', 'temen'])
# set(['hengel', 'leghen'])
# set(['treem', 'temer', 'meter'])
# set(['these', 'sheet'])
# set(['reveil', 'liever', 'vleier', 'vierel'])
# set(['oliecarter', 'correlatie'])
# set(['pletsen', 'spleten', 'netspel', 'stelpen'])
# set(['kaplaars', 'pasklaar'])
# set(['boonstaak', 'staakboon'])
# set(['werktop', 'topwerk'])
# set(['rost', 'tros', 'rots', 'stro', 'tors'])
# set(['lastenkohier', 'katholiseren'])
# set(['rota', 'rato'])
# set(['elegie', 'eigeel'])
# set(['meikrans', 'nakermis'])
# set(['ongelovige', 'ongevoelig'])
# set(['serail', 'relais'])
# set(['knoedel', 'lokeend'])
# set(['naaste', 'senaat'])
# set(['rechte', 'echter'])
# set(['stegel', 'gestel'])
# set(['spaarkas', 'kaasrasp'])
# set(['operadirigent', 'rdinatiegroep'])
# set(['dirigeren', 'dreinerig'])
# set(['tienen', 'nieten'])
# set(['mie', 'mei'])
# set(['vinder', 'vriend'])
# set(['sme', 'mes'])
# set(['stedeling', 'ingesteld'])
# set(['pluimveevlees', 'vleespluimvee'])
# set(['kervel', 'klever', 'krevel'])
# set(['nekvel', 'knevel', 'venkel', 'kleven'])
# set(['houtspaan', 'spaanhout'])
# set(['rieten', 'nieter', 'tieren', 'tiener', 'intree'])
# set(['klimaatfilm', 'filmklimaat'])
# set(['debuutalbum', 'albumdebuut'])
# set(['teratogene', 'teratogeen'])
# set(['koor', 'rook'])
# set(['moor', 'room'])
# set(['oord', 'door', 'rood'])
# set(['roof', 'foor'])
# set(['omstaander', 'ondermaats'])
# set(['gedragen', 'ngageerd', 'regendag'])
# set(['suikerkristal', 'kristalsuiker'])
# set(['termijnpacht', 'pachttermijn'])
# set(['radiospot', 'radiopost'])
# set(['lijnstuk', 'kustlijn'])
# set(['samisch', 'schisma'])
# set(['ernst', 'stern', 'trens', 'nerts', 'snert'])
# set(['raamkader', 'raadkamer'])
# set(['boekenstal', 'lastenboek', 'stalenboek'])
# set(['goedleven', 'eendvogel'])
# set(['verdelgen', 'vergelden', 'verlengde'])
# set(['werkvakantie', 'vakantiewerk'])
# set(['bouwsteen', 'steenbouw', 'onbewuste'])
# set(['teems', 'smeet', 'meest'])
# set(['sluip', 'pluis'])
# set(['mager', 'gamer', 'geram', 'marge'])
# set(['verzien', 'vriezen', 'veinzer'])
# set(['saksen', 'kassen'])
# set(['volt', 'vlot'])
# set(['ingestort', 'snotterig'])
# set(['troon', 'toorn'])
# set(['ogelijk', 'goelijk'])
# set(['iets', 'site'])
# set(['spuitnevel', 'nevelspuit'])
# set(['leader', 'dealer', 'alrede'])
# set(['motte', 'motet', 'totem'])
# set(['loeder', 'roedel'])
# set(['veerring', 'verering'])
# set(['bankdisconto', 'discontobank'])
# set(['akker', 'kaker'])
# set(['knapenkoor', 'ankerknoop'])
# set(['korren', 'ronker'])
# set(['poster', 'sproet', 'presto'])
# set(['pakketbom', 'bompakket'])
# set(['seksloos', 'soloseks'])
# set(['soep', 'epos', 'pose', 'oeps', 'peso', 'poes'])
# set(['litteken', 'kittelen'])
# set(['adel', 'lade', 'deal'])
# set(['isolatievloer', 'vloerisolatie'])
# set(['verluchting', 'luchtvering'])
# set(['reprint', 'printer'])
# set(['moordverhaal', 'droomverhaal'])
# set(['generen', 'negeren', 'regenen'])
# set(['glaasje', 'laagjes'])
# set(['vliegkunst', 'kunstvlieg'])
# set(['down', 'wond'])
# set(['parktuin', 'tuinpark'])
# set(['witgrijs', 'grijswit'])
# set(['keuzepakket', 'pakketkeuze'])
# set(['veterschoen', 'schoenveter'])
# set(['triode', 'editor'])
# set(['controlekaart', 'kaartcontrole'])
# set(['petit', 'pitte'])
# set(['havenwerk', 'werkhaven'])
# set(['griet', 'terig'])
# set(['blaas', 'balsa'])
# set(['museumtram', 'trammuseum'])
# set(['begrotingsbeleid', 'beleidsbegroting'])
# set(['wereldvoetbal', 'voetbalwereld'])
# set(['restoren', 'sorteren'])
# set(['rijst', 'trijs'])
# set(['dropen', 'ponder', 'pernod'])
# set(['rookstel', 'klooster', 'kletsoor'])
# set(['ontluizen', 'ontzuilen'])
# set(['dagschool', 'schooldag'])
# set(['premieomzet', 'omzetpremie'])
# set(['stopsein', 'seinpost'])
# set(['ausputzer', 'rustpauze'])
# set(['veldvoetbal', 'voetbalveld'])
# set(['serveren', 'verseren'])
# set(['waterafvoer', 'afvoerwater'])
# set(['uitvoer', 'voiture'])
# set(['veranderingsbeleid', 'beleidsverandering'])
# set(['lob', 'blo', 'bol', 'lbo'])
# set(['mbo', 'bom'])
# set(['ebo', 'beo', 'boe'])
# set(['spaardeel', 'speelaard'])
# set(['presse', 'preses'])
# set(['stopsein', 'seinpost'])
# set(['sample', 'lesmap'])
# set(['hoekband', 'handboek'])
# set(['asiel', 'salie'])
# set(['kwats', 'kwast'])
# set(['eronder', 'roderen', 'roerend'])
# set(['uitvagen', 'uitgaven'])
# set(['hakblok', 'blokhak'])
# set(['blokboek', 'boekblok'])
# set(['kluiterig', 'liturgiek'])
# set(['lekken', 'knekel'])
# set(['uitloodsen', 'loonstudie', 'studieloon'])
# set(['kruisridder', 'ridderkruis'])
# set(['stuiteren', 'urinetest'])
# set(['vergisten', 'gevernist'])
# set(['wiggen', 'weging'])
# set(['latei', 'talie'])
# set(['hollandse', 'salonheld'])
# set(['vendel', 'levend', 'delven'])
# set(['angst', 'stang'])
# set(['verkiezingsraad', 'raadsverkiezing'])
# set(['spar', 'pars', 'rasp'])
# set(['masten', 'matsen'])
# set(['gek', 'keg'])
# set(['leg', 'gel'])
# set(['pokziekte', 'kopziekte'])
# set(['koperrood', 'kooporder', 'roodkoper'])
# set(['soms', 'smos'])
# set(['boersheid', 'soberheid'])
# set(['dubbelglas', 'dubbelslag'])
# set(['knipster', 'pinkster'])
# set(['steendruk', 'redekunst'])
# set(['badbroek', 'broedbak'])
# set(['schroefworm', 'wormschroef'])
# set(['klaroenstoot', 'kantoorstoel'])
# set(['azen', 'zena'])
# set(['vaal', 'aval', 'lava'])
# set(['biertent', 'bitteren'])
# set(['zaadolie', 'oliezaad'])
# set(['testrun', 'stunter'])
# set(['inzijpelen', 'zielenpijn'])
# set(['reflatie', 'relatief'])
# set(['polsband', 'plonsbad'])
# set(['stuiteren', 'urinetest'])
# set(['tekenveld', 'veldteken'])
# set(['loevert', 'revolte'])
# set(['slagarm', 'armslag'])
# set(['rijgsteek', 'geestrijk'])
# set(['asem', 'same'])
# set(['staartloos', 'staalsoort'])
# set(['beloeren', 'boeleren'])
# set(['trajectdeel', 'deeltraject'])
# set(['molen', 'lemon', 'olmen'])
# set(['razend', 'zander'])
# set(['scoren', 'censor'])
# set(['kaderwerk', 'werkkader', 'dakwerker'])
# set(['bubblejet', 'bubbeltje'])
# set(['aanvanger', 'aanvragen', 'aangraven'])
# set(['tafella', 'latafel'])
# set(['leus', 'lues'])
# set(['wener', 'weren'])
# set(['beenmerg', 'mergbeen'])
# set(['bondsvolk', 'volksbond'])
# set(['steak', 'skate', 'aktes', 'kaste'])
# set(['ambulancehulp', 'hulpambulance'])
# set(['achtenzestig', 'zesentachtig'])
# set(['maal', 'lama', 'alma'])
# set(['trekvogel', 'vogeltrek'])
# set(['knipogen', 'pinkogen'])
# set(['mensenwerk', 'werkmensen'])
# set(['krantensite', 'tennisraket'])
# set(['raai', 'aria'])
# set(['paletmes', 'teamspel'])
# set(['waterslak', 'staalwerk'])
# set(['loofrijk', 'lijkroof'])
# set(['partnertoeslag', 'toeslagpartner'])
# set(['stomkop', 'opkomst'])
# set(['drankwet', 'tandwerk'])
# set(['stil', 'list', 'lits'])
# set(['nepal', 'palen', 'plane', 'panel'])
# set(['bara', 'arab', 'baar'])
# set(['baas', 'saba'])
# set(['vruchtboom', 'boomvrucht'])
# set(['toesturen', 'toerusten'])
# set(['jaarboek', 'boekjaar'])
# set(['gangreen', 'neergang'])
# set(['praatstoel', 'praalstoet'])
# set(['vederbal', 'bladveer'])
# set(['kleien', 'kielen', 'kleine', 'keilen'])
# set(['verraad', 'vaarder'])
# set(['tor', 'rot'])
# set(['achterwerk', 'weerkracht'])
# set(['canadees', 'canadese'])
# set(['lering', 'reling'])
# set(['ooit', 'tooi'])
# set(['not', 'ton'])
# set(['lto', 'tol', 'lot'])
# set(['haarwortel', 'wortelhaar'])
# set(['trof', 'fort'])
# set(['snelle', 'ellens'])
# set(['verhoeren', 'heroveren'])
# set(['tod', 'dot'])
# set(['pariteit', 'partitie'])
# set(['subvragen', 'vragenbus'])
# set(['biervat', 'vatbier'])
# set(['teems', 'smeet', 'meest'])
# set(['bovendien', 'boveneind'])
# set(['waterput', 'putwater'])
# set(['bloembol', 'bolbloem'])
# set(['diplomeren', 'imploderen'])
# set(['standaardtaal', 'taalstandaard'])
# set(['hopakker', 'ophakker'])
# set(['sleet', 'steel', 'leest', 'leste', 'stele'])
# set(['snoet', 'steno', 'noest'])
# set(['azteken', 'zeekant'])
# set(['wolkam', 'kamwol'])
# set(['steenblok', 'belkosten'])
# set(['booreiland', 'loonarbeid'])
# set(['rieten', 'nieter', 'tieren', 'tiener', 'intree'])
# set(['werkrelatie', 'werkatelier'])
# set(['sprits', 'strips'])
# set(['wandkleed', 'wandeldek'])
# set(['gezel', 'zegel'])
# set(['kwinkeleren', 'weerklinken'])
# set(['diocese', 'diocees'])
# set(['oppervlaktewater', 'wateroppervlakte'])
# set(['schuimbad', 'badschuim'])
# set(['etgroen', 'groeten', 'groente'])
# set(['onderzoeksafdeling', 'afdelingsonderzoek'])
# set(['dienstlijn', 'lijndienst'])
# set(['invoerregel', 'voeringleer'])
# set(['doorkneden', 'doordenken'])
# set(['installatieproces', 'procesinstallatie'])
# set(['retailer', 'realiter'])
# set(['bse', 'bes'])
# set(['ranken', 'kranen', 'karnen'])
# set(['slagman', 'manslag'])
# set(['magma', 'gamma'])
# set(['bekervoetbal', 'voetbalbeker'])
# set(['terloops', 'loopster', 'poolster'])
# set(['verkloten', 'vertolken'])
# set(['mazelen', 'zamelen'])
# set(['resem', 'smeer', 'meers'])
# set(['tuinkers', 'nierstuk', 'kruisnet', 'struiken'])
# set(['vergasten', 'vragenset'])
# set(['stroomproductie', 'productiestroom'])
# set(['masculien', 'masculine'])
# set(['wandelweg', 'wegwandel'])
# set(['snater', 'staren', 'ratsen'])
# set(['tinken', 'inkten'])
# set(['kolere', 'koeler'])
# set(['nteel', 'netel', 'telen', 'lente'])
# set(['kazen', 'zaken'])
# set(['galvanometer', 'taalvermogen'])
# set(['koto', 'toko', 'koot'])
# set(['museumtram', 'trammuseum'])
# set(['report', 'pretor'])
# set(['schoolsport', 'sportschool'])
# set(['onderbroek', 'doorbreken'])
# set(['rondeel', 'doleren', 'rodelen'])
# set(['studiekop', 'kopstudie'])
# set(['planlast', 'slaplant'])
# set(['zowel', 'zwoel'])
# set(['beleidsteam', 'mediabestel'])
# set(['zwade', 'dwaze'])
# set(['rolsteen', 'entresol'])
# set(['onderstam', 'omstander'])
# set(['betonstaal', 'staalbeton'])
# set(['vijfenzestig', 'zesenvijftig'])
# set(['ogentroost', 'ongetroost', 'ostrogoten'])
# set(['soortement', 'toestormen', 'toestromen'])
# set(['ontwerpstijl', 'ontwerplijst'])
# set(['sirene', 'sieren', 'seiner'])
# set(['spritsen', 'spinster'])
# set(['gedaan', 'gaande', 'agenda'])
# set(['rijkaard', 'aardrijk'])
# set(['gelen', 'legen', 'engel'])
# set(['aker', 'rake'])
# set(['gevoelig', 'gelovige'])
# set(['waterkom', 'teamwork'])
# set(['gieren', 'eniger'])
# set(['dialect', 'citadel'])
# set(['kalenderjaar', 'jaarkalender'])
# set(['europese', 'europees'])
# set(['menu', 'meun'])
# set(['ontembaar', 'metrobaan', 'ramboetan'])
# set(['dringen', 'grinden'])
# set(['basisbelasting', 'belastingbasis'])
# set(['goederenproductie', 'productiegoederen'])
# set(['randhagel', 'lagerhand'])
# set(['formeren', 'reformen'])
# set(['zeeloods', 'zedeloos'])
# set(['doorstromen', 'onderstroom'])
# set(['omdraai', 'diorama'])
# set(['luchttoevoer', 'toevoerlucht'])
# set(['spuitwater', 'waterspuit'])
# set(['kotter', 'kortte', 'tekort'])
# set(['gifangel', 'afliggen'])
# set(['waarheen', 'weerhaan'])
# set(['schoolsite', 'scheisloot'])
# set(['uitkramen', 'tuinkamer'])
# set(['rdinaat', 'radiant'])
# set(['dieptescherpte', 'scherptediepte'])
# set(['praktijkonderwijs', 'onderwijspraktijk'])
# set(['glimmen', 'lemming'])
# set(['beginne', 'benigne'])
# set(['klif', 'flik'])
# set(['stedenbouwer', 'onderbewuste'])
# set(['zatladder', 'ladderzat'])
# set(['pandoeren', 'operanden'])
# set(['stuwraket', 'kustwater'])
# set(['aflaat', 'fataal'])
# set(['atelier', 'relatie'])
# set(['cardiaal', 'radicaal'])
# set(['glasraam', 'gasalarm'])
# set(['waterglas', 'waterslag'])
# set(['vijl', 'vlij'])
# set(['remming', 'grimmen'])
# set(['bankrente', 'rentebank'])
# set(['bronolie', 'oliebron'])
# set(['uitslepen', 'uitspelen', 'speeltuin'])
# set(['credit', 'direct'])
# set(['kut', 'tuk'])
# set(['rechtstand', 'standrecht'])
# set(['aanboorden', 'ondoenbaar'])
# set(['familiecircus', 'circusfamilie'])
# set(['bladeren', 'rendabel', 'balderen'])
# set(['fakir', 'kafir'])
# set(['hockeyveld', 'veldhockey'])
# set(['studievak', 'vakstudie'])
# set(['die', 'edi', 'dei'])
# set(['reppen', 'nepper'])
# set(['baf', 'afb'])
# set(['vensterrichel', 'renteverschil'])
# set(['leidingbuis', 'buisleiding'])
# set(['begraven', 'bevragen'])
# set(['vermetel', 'veelterm'])
# set(['reisauto', 'autoreis'])
# set(['kaard', 'draak'])
# set(['bekervoetbal', 'voetbalbeker'])
# set(['blij', 'bijl'])
# set(['zolen', 'lozen'])
# set(['kalanderen', 'kandelaren'])
# set(['bridge', 'geribd'])
# set(['berkoen', 'broeken', 'bekoren', 'beroken'])
# set(['standlicht', 'lichtstand'])
# set(['neder', 'deren', 'deern', 'erden', 'reden', 'neerd'])
# set(['wereldhit', 'helderwit'])
# set(['voorzitster', 'voorzitters'])
# set(['joint', 'ontij'])
# set(['detonatie', 'denotatie'])
# set(['gronddeel', 'onderlegd', 'dengordel'])
# set(['werkavond', 'avondwerk'])
# set(['peinzen', 'inzepen'])
# set(['gespeel', 'gesleep'])
# set(['leder', 'deler'])
# set(['ontroerd', 'rondtoer'])
# set(['constructiestaal', 'staalconstructie'])
# set(['mud', 'dum'])
# set(['mug', 'gum'])
# set(['limiettijd', 'tijdlimiet'])
# set(['seder', 'reeds'])
# set(['toonkamer', 'atoomkern'])
# set(['drankwet', 'tandwerk'])
# set(['eeltlaag', 'teellaag'])
# set(['eremiet', 'temeier'])
# set(['toneeltekst', 'teksttoneel'])
# set(['bordes', 'broeds'])
# set(['daad', 'dada'])
# set(['wereldcultuur', 'cultuurwereld'])
# set(['nteren', 'renten'])
# set(['kwartje', 'jatwerk'])
# set(['strafcel', 'celstraf'])
# set(['vechtarend', 'verdachten'])
# set(['stopnaald', 'stolpnaad'])
# set(['handelen', 'nehandel'])
# set(['huisslacht', 'slachthuis'])
# set(['studieplan', 'planstudie'])
# set(['breukzak', 'zakbreuk'])
# set(['meedogend', 'mededogen'])
# set(['turbine', 'tribune'])
# set(['abel', 'albe', 'leba'])
# set(['opkopen', 'oppoken'])
# set(['opkappen', 'papenkop'])
# set(['tekenschrift', 'schriftteken'])
# set(['rectoraal', 'correlaat'])
# set(['baksteen', 'etensbak'])
# set(['treinen', 'interen', 'interne'])
# set(['dreven', 'derven'])
# set(['tester', 'street', 'setter'])
# set(['lor', 'rol'])
# set(['roo', 'oor'])
# set(['ocr', 'roc', 'cro'])
# set(['oer', 'ore', 'roe'])
# set(['org', 'rog'])
# set(['denier', 'einder', 'dieren'])
# set(['beest', 'beste'])
# set(['gloeiend', 'ongeleid'])
# set(['regelmaat', 'maatregel'])
# set(['viskweek', 'kweekvis'])
# set(['raketbal', 'belkaart'])
# set(['informatiemarkt', 'marktinformatie'])
# set(['opleidingsbedrijf', 'bedrijfsopleiding'])
# set(['drent', 'trend'])
# set(['ernst', 'stern', 'trens', 'nerts', 'snert'])
# set(['prune', 'puren'])
# set(['prei', 'pier'])
# set(['zoeven', 'evenzo'])
# set(['pret', 'terp'])
# set(['liederen', 'elideren', 'riedelen'])
# set(['klankbord', 'brandklok'])
# set(['pieklast', 'plastiek'])
# set(['latrine', 'railnet'])
# set(['morgenster', 'regenstorm'])
# set(['blonde', 'bondel'])
# set(['raathoning', 'honingraat'])
# set(['kopschool', 'koolschop'])
# set(['denken', 'kneden'])
# set(['kneder', 'erkend', 'denker'])
# set(['bediende', 'bedieden'])
# set(['nomade', 'monade'])
# set(['jetski', 'kistje'])
# set(['slotletter', 'letterslot'])
# set(['radiospot', 'radiopost'])
# set(['pelsjas', 'slapjes'])
# set(['bedrijfsingenieur', 'ingenieursbedrijf'])
# set(['steelgat', 'gestalte'])
# set(['oertekst', 'teerkost'])
# set(['veldproef', 'proefveld'])
# set(['tartan', 'tantra'])
# set(['bouwer', 'berouw'])
# set(['balinese', 'albinees', 'abseilen', 'balinees', 'baseline'])
# set(['drukpers', 'persdruk'])
# set(['begin', 'benig'])
# set(['lus', 'sul'])
# set(['opgraven', 'opvragen'])
# set(['kort', 'trok', 'krot'])
# set(['zever', 'vreze'])
# set(['trof', 'fort'])
# set(['rost', 'tros', 'rots', 'stro', 'tors'])
# set(['ablaut', 'tabula'])
# set(['opslagrente', 'renteopslag'])
# set(['brandstofmotor', 'motorbrandstof'])
# set(['inkomensoverdracht', 'overdrachtsinkomen'])
# set(['bouwdag', 'dagbouw'])
# set(['releveren', 'reveleren'])
# set(['carne', 'racen'])
# set(['benard', 'braden'])
# set(['ontbieden', 'toebinden'])
# set(['kletspraat', 'kerstplaat'])
# set(['rechtsvordering', 'vorderingsrecht'])
# set(['zege', 'zeeg'])
# set(['basisset', 'bassiste'])
# set(['topatleet', 'topatlete'])
# set(['cash', 'scha'])
# set(['bladgoud', 'goudblad'])
# set(['cle', 'cel'])
# set(['moveren', 'vomeren'])
# set(['debiel', 'beleid'])
# set(['pediater', 'predatie'])
# set(['image', 'magie', 'gamie'])
# set(['cultuurschok', 'cultuurshock'])
# set(['reactie', 'creatie'])
# set(['doopwater', 'waterdoop'])
# set(['schip', 'chips'])
# set(['houtstapel', 'stapelhout'])
# set(['verdoen', 'onvrede'])
# set(['rietje', 'eterij'])
# set(['brandstofolie', 'oliebrandstof'])
# set(['zesenzeventig', 'zevenenzestig'])
# set(['nties', 'tiens', 'niets', 'niste'])
# set(['hulpprogramma', 'programmahulp'])
# set(['bloeder', 'bordeel'])
# set(['bonkerig', 'bekoring'])
# set(['glasfiber', 'fiberglas'])
# set(['cautie', 'auctie'])
# set(['kaasmaker', 'kaaskamer'])
# set(['converseren', 'conserveren'])
# set(['blokkade', 'kladboek'])
# set(['loven', 'novel'])
# set(['xxiv', 'xxvi'])
# set(['bus', 'sub', 'usb'])
# set(['wasbeurt', 'waterbus'])
# set(['travers', 'verrast'])
# set(['werktop', 'topwerk'])
# set(['roet', 'toer'])
# set(['toef', 'ofte'])
# set(['randweg', 'redwang'])
# set(['delging', 'liggend', 'gelding'])
# set(['alkanna', 'lankaan'])
# set(['spotprijs', 'prijsstop'])
# set(['laaien', 'alinea'])
# set(['biest', 'beits', 'biets'])
# set(['bunkerolie', 'oliebunker'])
# set(['mantelpak', 'kapmantel', 'platmaken', 'lampetkan'])
# set(['drevelen', 'verdelen', 'verleden'])
# set(['banier', 'branie'])
# set(['spanne', 'spanen'])
# set(['ondervraging', 'ondergraving'])
# set(['negenentachtig', 'achtennegentig'])
# set(['geldtas', 'stageld'])
# set(['stierf', 'frites', 'friste'])
# set(['arterieklem', 'karmelieter'])
# set(['competitiesport', 'sportcompetitie'])
# set(['achtervering', 'verachtering'])
# set(['streek', 'steker', 'rekest', 'sterke', 'ekster'])
# set(['stoer', 'roest', 'store'])
# set(['kine', 'kien', 'knie'])
# set(['altereren', 'relateren'])
# set(['knik', 'kink'])
# set(['tam', 'atm', 'mat'])
# set(['tui', 'uit'])
# set(['welken', 'kwelen'])
# set(['visangel', 'seinvlag'])
# set(['wandtegel', 'tegelwand'])
# set(['ier', 'rie', 'rei'])
# set(['tie', 'iet'])
# set(['lei', 'iel'])
# set(['eerstdaags', 'stageadres'])
# set(['klantenpas', 'plantenkas'])
# set(['montagefoto', 'fotomontage'])
# set(['alia', 'laai'])
# set(['faal', 'laaf', 'alfa'])
# set(['laag', 'gala', 'gaal'])
# set(['taal', 'laat', 'aalt'])
# set(['woestijnzand', 'zandwoestijn'])
# set(['bouwsteen', 'steenbouw', 'onbewuste'])
# set(['oslo', 'loos', 'solo'])
# set(['drops', 'dorps'])
# set(['raamwerk', 'waarmerk'])
# set(['bevoordeling', 'bloedvoering'])
# set(['orni', 'noir', 'iron'])
# set(['verzoendag', 'zandgroeve'])
# set(['veerdruk', 'drukveer'])
# set(['smetstof', 'meststof'])
# set(['stemvork', 'mestvork'])
# set(['galzuur', 'glazuur'])
# set(['ingestort', 'snotterig'])
# set(['gastland', 'slagtand'])
# set(['kranke', 'rakken', 'kraken', 'kanker'])
# set(['kraker', 'rakker'])
# set(['landheer', 'herladen'])
# set(['paret', 'apert', 'rapte', 'pater'])
# set(['karveel', 'leervak'])
# set(['meelezer', 'zeemleer'])
# set(['trede', 'teder'])
# set(['tiet', 'teit'])
# set(['generen', 'negeren', 'regenen'])
# set(['kraanwater', 'waterkraan'])
# set(['ongenegen', 'negenogen'])
# set(['weegstoel', 'woelgeest'])
# set(['debiel', 'beleid'])
# set(['tafelgerei', 'telegrafie'])
# set(['vervoersbedrijf', 'bedrijfsvervoer'])
# set(['reptiel', 'pleiter'])
# set(['voertaal', 'overlaat'])
# set(['baanrace', 'racebaan'])
# set(['lonk', 'knol'])
# set(['dalweiden', 'weideland'])
# set(['kostendeel', 'neteldoeks'])
# set(['ponsen', 'nopens'])
# set(['meterslang', 'armslengte'])
# set(['verkondigen', 'overdenking'])
# set(['viskweek', 'kweekvis'])
# set(['scherven', 'schreven'])
# set(['broei', 'boire'])
# set(['verenigen', 'eennervig'])
# set(['grondpacht', 'pachtgrond'])
# set(['iemand', 'medina'])
# set(['polyamide', 'olympiade'])
# set(['vlezen', 'zelven'])
# set(['piekeren', 'kieperen'])
# set(['buitenrand', 'uitbranden'])
# set(['week', 'kwee'])
# set(['geiser', 'gereis'])
# set(['soleerd', 'soldeer'])
# set(['stalen', 'lasten'])
# set(['zeil', 'ziel'])
# set(['noodkerk', 'onderkok'])
# set(['kosten', 'stoken', 'kotsen', 'knoest'])
# set(['pariteit', 'partitie'])
# set(['diernaam', 'marinade'])
# set(['kranke', 'rakken', 'kraken', 'kanker'])
# set(['kransje', 'sjanker'])
# set(['weerkundig', 'wiegendruk'])
# set(['appelgroen', 'galopperen'])
# set(['grimeren', 'migreren', 'meerring'])
# set(['bastonnade', 'onbestaand'])
# set(['falset', 'afstel'])
# set(['klapbaar', 'krabpaal'])
# set(['kurken', 'rukken'])
# set(['ongel', 'logen'])
# set(['jaarboek', 'boekjaar'])
# set(['kwestie', 'kieswet'])
# set(['voerman', 'omvaren', 'overman'])
# set(['bloeder', 'bordeel'])
# set(['klompschoen', 'schoenklomp'])
# set(['ent', 'net', 'nte', 'ten'])
# set(['verlokken', 'enkelvork'])
# set(['tuinhout', 'houttuin'])
# set(['grasmat', 'armsgat'])
# set(['massageolie', 'oliemassage'])
# set(['badstrand', 'strandbad'])
# set(['kerkering', 'keerkring'])
# set(['ontelbaar', 'laborante'])
# set(['toptarief', 'portatief'])
# set(['draadglas', 'glasdraad'])
# set(['marinetop', 'patroniem'])
# set(['gescheiden', 'geschieden'])
# set(['troepentransport', 'transporttroepen'])
# set(['bureauonderzoek', 'onderzoekbureau'])
# set(['kaars', 'askar'])
# set(['nijd', 'dijn'])
# set(['talentmanagement', 'managementtalent'])
# set(['nvloed', 'vloden', 'dolven', 'vondel'])
# set(['ploegwerk', 'werkploeg', 'oplegwerk'])
# set(['lokaaltrein', 'interlokaal'])
# set(['salonmuziek', 'muzieksalon'])
# set(['verkazen', 'verzaken'])
# set(['enigen', 'neigen'])
# set(['onderzoekruimte', 'ruimteonderzoek'])
# set(['gieren', 'eniger'])
# set(['builen', 'beulin'])
# set(['krachtmens', 'menskracht'])
# set(['talentmanagement', 'managementtalent'])
# set(['ijseend', 'eindjes'])
# set(['gust', 'guts', 'stug'])
# set(['leeskaart', 'aalsteker'])
# set(['elders', 'selder'])
# set(['opslagrente', 'renteopslag'])
# set(['melen', 'lemen'])
# set(['armenwijk', 'wijnmaker'])
# set(['zeepvlokken', 'vlokkenzeep'])
# set(['loeven', 'voelen'])
# set(['kindertuin', 'uitdrinken'])
# set(['eervol', 'loever', 'voeler'])
# set(['nipper', 'rippen'])
# set(['kasgeld', 'dekglas', 'geldkas'])
# set(['opgeven', 'opvegen'])
# set(['oliepalm', 'lampolie', 'palmolie', 'olielamp'])
# set(['pasta', 'tapas', 'spaat'])
# set(['rara', 'raar'])
# set(['berkenolie', 'boerenkiel'])
# set(['rommel', 'mormel', 'lommer'])
# set(['partnerkeus', 'supertanker'])
# set(['toesluiten', 'uitstoelen'])
# set(['herstarten', 'herstraten'])
# set(['lievig', 'veilig'])
# set(['tonner', 'tornen', 'tronen'])
# set(['slagman', 'manslag'])
# set(['jaarinkomsten', 'inkomstenjaar'])
# set(['aanvoelen', 'aanloeven'])
# set(['eindgroep', 'diepgroen'])
# set(['amerikaan', 'naaikamer'])
# set(['bedroevend', 'eedverbond'])
# set(['orkest', 'stoker', 'trekos', 'koster', 'korset'])
# set(['avers', 'versa'])
# set(['voortrein', 'rietvoorn'])
# set(['tabaksteler', 'bestelkaart'])
# set(['strotklep', 'stortklep'])
# set(['reinette', 'eterniet', 'retentie'])
# set(['suikerriet', 'rietsuiker'])
# set(['akst', 'taks', 'stak', 'kast'])
# set(['gebel', 'beleg'])
# set(['donorgeld', 'gronddoel'])
# set(['geloken', 'kogelen'])
# set(['verdoemen', 'vermoeden'])
# set(['donzen', 'zonden'])
# set(['uitslepen', 'uitspelen', 'speeltuin'])
# set(['verhelen', 'herleven'])
# set(['stokerij', 'kosterij'])
# set(['hoeren', 'nehoer'])
# set(['pleet', 'tepel'])
# set(['verluchting', 'luchtvering'])
# set(['bilspier', 'pilsbier'])
# set(['sector', 'escort', 'croste', 'cortes'])
# set(['gemeden', 'gemeend'])
# set(['oesterparel', 'pareloester'])
# set(['lastgeld', 'stalgeld'])
# set(['overstroming', 'roestvorming'])
# set(['kostenbasis', 'basiskosten'])
# set(['breuklijn', 'lijnbreuk'])
# set(['werkkopie', 'koperwiek'])
# set(['caret', 'recta', 'carte'])
# set(['roeven', 'onvree', 'voeren'])
# set(['volvoeren', 'voorleven'])
# set(['onderdijk', 'dodenrijk'])
# set(['noodgeld', 'geldnood'])
# set(['punaise', 'uiensap'])
# set(['kansel', 'lakens', 'slaken'])
# set(['topbankier', 'breakpoint'])
# set(['spuit', 'stuip', 'puist'])
# set(['weerleggen', 'wegregelen'])
# set(['geleidraad', 'edelaardig'])
# set(['nootolie', 'olienoot'])
# set(['reactorkern', 'kernreactor'])
# set(['menu', 'meun'])
# set(['voetbalclub', 'clubvoetbal'])
# set(['booggewelf', 'gewelfboog'])
# set(['boekanier', 'ankerboei'])
# set(['leasing', 'eiglans'])
# set(['vormtaal', 'taalvorm'])
# set(['raapsteel', 'aalstreep', 'ereplaats'])
# set(['overgang', 'voergang'])
# set(['relatering', 'alertering'])
# set(['torso', 'toros', 'soort'])
# set(['chromo', 'chroom'])
# set(['spelcomputer', 'computerspel'])
# set(['somberen', 'bemorsen'])
# set(['filmmaken', 'afklimmen'])
# set(['surrogaatkoffie', 'koffiesurrogaat'])
# set(['diernaam', 'marinade'])
# set(['klapzoen', 'zaklopen'])
# set(['voetbaltafel', 'tafelvoetbal'])
# set(['verdrieten', 'diverteren'])
# set(['toetrekken', 'koketteren'])
# set(['torenen', 'onteren', 'noteren'])
# set(['premiebouw', 'bouwpremie'])
# set(['bloed', 'blode', 'doble'])
# set(['krol', 'lork'])
# set(['kort', 'trok', 'krot'])
# set(['stuk', 'kust'])
# set(['dengue', 'deugen'])
# set(['drukbelasting', 'belastingdruk'])
# set(['werkuur', 'uurwerk'])
# set(['besturing', 'berusting'])
# set(['bereid', 'bieder'])
# set(['okra', 'orka'])
# set(['gesel', 'leges'])
# set(['sleuven', 'leuvens'])
# set(['kint', 'inkt'])
# set(['ringvinger', 'vingerring'])
# set(['reisdag', 'dagreis'])
# set(['gelde', 'degel', 'gleed'])
# set(['paardmens', 'ampersand'])
# set(['haagroos', 'hoogaars'])
# set(['reisgenoot', 'soorteigen'])
# set(['bevelslijn', 'levensblij'])
# set(['soep', 'epos', 'pose', 'oeps', 'peso', 'poes'])
# set(['step', 'pest', 'pets'])
# set(['pektoorts', 'toporkest'])
# set(['su', 'us'])
# set(['ijl', 'lij'])
# set(['kwatrijn', 'kwartijn'])
# set(['sterkteleer', 'letterreeks'])
# set(['gebinte', 'beignet'])
# set(['landwijn', 'wijnland'])
# set(['lastgeving', 'vliegangst', 'vlaggenist', 'vastliggen'])
# set(['ketelaar', 'leertaak'])
# set(['stalbeen', 'belasten'])
# set(['leerrede', 'redeleer'])
# set(['opsieren', 'sproeien'])
# set(['trapstoel', 'tarotspel'])
# set(['centiem', 'centime'])
# set(['vergaring', 'gravering'])
# set(['artistiek', 'keratitis'])
# set(['hogere', 'gehore'])
# set(['nonkel', 'klonen', 'lonken'])
# set(['router', 'retour'])
# set(['schokeffect', 'shockeffect'])
# set(['kenia', 'nakie'])
# set(['data', 'adat'])
# set(['etmaal', 'metaal'])
# set(['onderhout', 'onthouder'])
# set(['modelkeuze', 'keuzemodel'])
# set(['beraden', 'bedaren'])
# set(['manchet', 'matchen'])
# set(['voorn', 'vroon'])
# set(['pruimer', 'primeur'])
# set(['prijsvork', 'vrijkorps'])
# set(['engelse', 'geselen'])
# set(['mestvee', 'stemvee'])
# set(['doorrennen', 'ordonneren'])
# set(['bierfles', 'lesbrief'])
# set(['snap', 'span'])
# set(['nestei', 'tensie', 'nietes'])
# set(['systeemverf', 'verfsysteem'])
# set(['nesten', 'stenen'])
# set(['stelen', 'lentes', 'sleten', 'nestel'])
# set(['reuzin', 'ruizen'])
# set(['tijdreis', 'reistijd'])
# set(['knar', 'karn', 'rank'])
# set(['collage', 'collega'])
# set(['reutelaar', 'leuteraar'])
# set(['breeduit', 'debiteur'])
# set(['wreker', 'werker'])
# set(['teren', 'entre', 'reten', 'neert', 'renet', 'rente', 'enter', 'terne'])
# set(['stater', 'taster'])
# set(['beleidsonderzoek', 'onderzoeksbeleid'])
# set(['wreken', 'werken'])
# set(['schrijfles', 'schrijfsel'])
# set(['sassen', 'assens'])
# set(['indigen', 'deining'])
# set(['duikerhelm', 'helmduiker'])
# set(['pedologisch', 'logopedisch'])
# set(['huiswijn', 'wijnhuis'])
# set(['waterleiding', 'leidingwater'])
# set(['waterijs', 'ijswater'])
# set(['kraangeld', 'geldkraan'])
# set(['uitstralen', 'neutralist'])
# set(['indrogen', 'ordening'])
# set(['solostem', 'stemloos'])
# set(['bebloemd', 'bloembed'])
# set(['marktrente', 'rentemarkt'])
# set(['leidingbuis', 'buisleiding'])
# set(['pelorie', 'poelier'])
# set(['haringnet', 'hantering'])
# set(['huisuitzetting', 'uithuiszetting'])
# set(['vres', 'vers'])
# set(['bloedneus', 'subdoelen'])
# set(['gidsrol', 'slordig'])
# set(['noodnet', 'ontdoen'])
# set(['geien', 'enige', 'eigen', 'genie'])
# set(['grensprovincie', 'provinciegrens'])
# set(['opt', 'pot', 'top'])
# set(['belijnen', 'bijlenen'])
# set(['bunkerkolen', 'kolenbunker'])
# set(['sportverleden', 'vensterdorpel'])
# set(['lief', 'feil', 'file'])
# set(['tief', 'feit'])
# set(['stuik', 'kuist'])
# set(['act', 'cat'])
# set(['kolken', 'konkel', 'lokken'])
# set(['designmeubel', 'meubeldesign'])
# set(['ste', 'est', 'set', 'ets'])
# set(['nokbalk', 'bolknak'])
# set(['ohm', 'hom'])
# set(['ad', 'da'])
# set(['ai', 'ia'])
# set(['ah', 'ha'])
# set(['al', 'la'])
# set(['na', 'an'])
# set(['as', 'sa'])
# set(['ar', 'ra'])
# set(['at', 'ta'])
# set(['song', 'gons'])
# set(['simmen', 'immens'])
# set(['triangel', 'aterling'])
# set(['rockjazz', 'jazzrock'])
# set(['lands', 'sland'])
# set(['langs', 'slang', 'glans'])
# set(['motte', 'motet', 'totem'])
# set(['gireren', 'griener'])
# set(['vrome', 'omver'])
# set(['toorts', 'troost'])
# set(['stofkam', 'afkomst'])
# set(['nadeel', 'dealen', 'adelen', 'nadele'])
# set(['negerin', 'grienen', 'greinen'])
# set(['gouvernementele', 'gouvernementeel'])
# set(['suikerbiet', 'bietsuiker'])
# set(['kopten', 'pekton'])
# set(['atelier', 'relatie'])
# set(['aleer', 'alree'])
# set(['normloon', 'loonnorm'])
# set(['ressource', 'resources'])
# set(['droge', 'droeg'])
# set(['stante', 'staten', 'tasten'])
# set(['stater', 'taster'])
# set(['dwarste', 'steward'])
# set(['nties', 'tiens', 'niets', 'niste'])
# set(['omscholing', 'mongolisch'])
# set(['moederfiets', 'stiefmoeder'])
# set(['bedilal', 'albedil'])
# set(['obstakel', 'bakstoel'])
# set(['tarwebloem', 'waterbloem'])
# set(['nest', 'sten'])
# set(['cirkelomtrek', 'kromtecirkel'])
# set(['nomografie', 'monografie'])
# set(['snippel', 'slippen'])
# set(['basalt', 'albast'])
# set(['geleider', 'gelieerd'])
# set(['ankerkader', 'kerkenraad'])
# set(['meten', 'meent', 'temen'])
# set(['eminent', 'inmeten'])
# set(['tuinkers', 'nierstuk', 'kruisnet', 'struiken'])
# set(['denier', 'einder', 'dieren'])
# set(['werkvakantie', 'vakantiewerk'])
# set(['verlegde', 'vergeeld', 'veergeld'])
# set(['condor', 'cordon'])
# ...
# set(['levensstaat', 'staatsleven'])
# set(['berin', 'brein'])
# set(['kostelijk', 'lijkkoets'])
# set(['gaten', 'agent'])
# set(['hosten', 'hotsen'])
# set(['mos', 'som'])
# set(['pom', 'mop'])
# set(['mol', 'olm', 'lom'])
# set(['beursgeld', 'geldbeurs'])
# set(['doorroken', 'kroonorde'])
# set(['beitsen', 'ebenist', 'bietsen'])
# set(['amalgaam', 'amalgama'])
# set(['doorlevering', 'veroordeling'])
# set(['megaster', 'gasmeter'])
# set(['wonder', 'worden', 'downer'])
# set(['gros', 'gors'])
# set(['trog', 'gort', 'grot'])
# set(['pias', 'pais', 'apis'])
# set(['afmelding', 'filmdagen'])
# set(['feestavond', 'avondfeest'])
# set(['apin', 'pain', 'pina', 'napi'])
# set(['blauwgroen', 'groenblauw'])
# set(['meerdelig', 'meerledig'])
# set(['siersteen', 'interesse'])
# set(['vierendelen', 'dierenleven'])
# set(['loverwerk', 'werkvloer'])
# set(['broodplank', 'boordplank'])
# set(['sater', 'aster'])
# set(['poularde', 'uploader'])
# set(['doorvechten', 'ochtendvoer'])
# set(['vooreind', 'voordien'])
# set(['tolvrij', 'vrijlot'])
# set(['regenmoesson', 'moessonregen'])
# set(['abs', 'bas'])
# set(['abt', 'bat', 'atb', 'tab'])
# set(['kikkerpoel', 'poelkikker'])
# set(['neuzelaar', 'auralezen'])
# set(['ratificatie', 'tarificatie'])
# set(['hazen', 'hanze'])
# set(['netwerkkabel', 'kabelnetwerk'])
# set(['acryl', 'lycra'])
# set(['bse', 'bes'])
# set(['waterval', 'welvaart'])
# set(['duopresentatie', 'presentatieduo'])
# set(['goldrush', 'drugshol'])
# set(['basiskennis', 'kennisbasis'])
# set(['kaderwerk', 'werkkader', 'dakwerker'])
# set(['luitspeler', 'lustprieel'])
# set(['tangaslip', 'plaatsing'])
# set(['kaolien', 'kaoline', 'oliekan'])
# set(['soep', 'epos', 'pose', 'oeps', 'peso', 'poes'])
# set(['watertor', 'waterrot'])
# set(['stookolie', 'oliestook'])
# set(['functieherstel', 'herstelfunctie'])
# set(['goog', 'gogo'])
# set(['wegedoorn', 'doorwegen'])
# set(['toog', 'goot'])
# set(['porto', 'poort', 'troop'])
# set(['megaohm', 'hommage'])
# set(['schroefoog', 'oogschroef'])
# set(['storten', 'stentor', 'tonster', 'snotter'])
# set(['ethologisch', 'theologisch'])
# set(['grimeren', 'migreren', 'meerring'])
# set(['groeptaal', 'taalgroep'])
# set(['testament', 'statement'])
# set(['doneren', 'onderen', 'ordenen'])
# set(['afperken', 'afpreken'])
# set(['topatleet', 'topatlete'])
# set(['cardiaal', 'radicaal'])
# set(['golden', 'ongeld', 'gondel'])
# set(['nvloed', 'vloden', 'dolven', 'vondel'])
# set(['grasweide', 'weidegras'])
# set(['cabinelift', 'liftcabine'])
# set(['orangist', 'organist'])
# set(['gedrein', 'nederig', 'dreigen', 'driegen'])
# set(['betalingssysteem', 'systeembelasting', 'belastingsysteem'])
# set(['inlegeren', 'engelrein', 'inregelen'])
# set(['biezen', 'bezien'])
# set(['leerzaam', 'zemelaar'])
# set(['ooft', 'foto'])
# set(['ramptrein', 'treinramp'])
# set(['verlener', 'verleren'])
# set(['lidwoord', 'roodwild'])
# set(['menigte', 'meeting'])
# set(['menage', 'manege'])
# set(['kuip', 'puik'])
# set(['teren', 'entre', 'reten', 'neert', 'renet', 'rente', 'enter', 'terne'])
# set(['gambiet', 'megabit'])
# set(['interactionele', 'interactioneel'])
# set(['zeulen', 'leuzen'])
# set(['eigener', 'energie'])
# set(['snak', 'kans'])
# set(['snap', 'span'])
# set(['puntkomma', 'kommapunt'])
# set(['kerkering', 'keerkring'])
# set(['rekentool', 'koeltoren'])
# set(['charmeren', 'marcheren'])
# set(['restgroep', 'stergroep'])
# set(['roomijs', 'ijsroom'])
# set(['blouse', 'boules'])
# set(['koter', 'korte'])
# set(['handelen', 'nehandel'])
# set(['ierse', 'eiser', 'serie', 'risee'])
# set(['moederklooster', 'kloostermoeder'])
# set(['rinkelen', 'kelnerin'])
# set(['etholoog', 'oogholte', 'theoloog'])
# set(['schoolvoetbal', 'voetbalschool'])
# set(['kastrol', 'kraslot'])
# set(['karbeel', 'breekal'])
# set(['paap', 'papa'])
# set(['spap', 'paps'])
# set(['cabinelift', 'liftcabine'])
# set(['knolvenkel', 'venkelknol'])
# set(['guyaan', 'guyana'])
# set(['geneeslijk', 'geneselijk'])
# set(['denke', 'deken'])
# set(['parel', 'lepra'])
# set(['daken', 'kaden'])
# set(['dreunen', 'neurend'])
# set(['bolle', 'bello'])
# set(['graveur', 'gravure'])
# set(['eindstreep', 'presidente'])
# set(['tas', 'sta', 'ast'])
# set(['vanwaar', 'waarvan'])
# set(['schoolonderzoek', 'onderzoekschool'])
# set(['seinvuur', 'vuursein'])
# set(['verloofd', 'loodverf'])
# set(['tai', 'tia'])
# set(['tak', 'kat'])
# set(['geleidraad', 'edelaardig'])
# set(['ad', 'da'])
# set(['metalband', 'badmantel'])
# set(['bodemwater', 'waterbodem'])
# set(['speelnoot', 'sleeptoon'])
# set(['cisplatine', 'plasticine'])
# set(['bridgen', 'beringd'])
# set(['koelkast', 'kakstoel'])
# set(['and', 'nda', 'dan', 'dna'])
# set(['pornofoto', 'portofoon'])
# set(['dra', 'rad', 'dar'])
# set(['dieprood', 'pierdood'])
# set(['loonschaal', 'schaalloon'])
# set(['dieptescherpte', 'scherptediepte'])
# set(['toveres', 'overste'])
# set(['verftube', 'tubeverf'])
# set(['sawa', 'waas'])
# set(['care', 'race', 'acre'])
# set(['graveltoernooi', 'tarievenoorlog'])
# set(['zenit', 'inzet'])
# set(['plas', 'laps', 'slap'])
# set(['badolie', 'oliebad'])
# set(['niksen', 'kennis'])
# set(['kernlid', 'linkerd'])
# set(['eregeld', 'geleerd'])
# set(['loven', 'novel'])
# set(['voerkosten', 'voortekens', 'voorsteken'])
# set(['vloer', 'lover'])
# set(['eindmeet', 'dementie'])
# set(['voorrem', 'oervorm'])
# set(['kist', 'kits', 'stik'])
# set(['bergzone', 'bezorgen'])
# set(['oogrand', 'nadroog'])
# set(['balinese', 'albinees', 'abseilen', 'balinees', 'baseline'])
# set(['riotgun', 'routing'])
# set(['sproeten', 'proesten', 'posteren'])
# set(['toesturen', 'toerusten'])
# set(['sinter', 'risten', 'ritsen'])
# set(['harmonie', 'mohairen'])
# set(['avondcursus', 'cursusavond'])
# set(['fortepiano', 'pianoforte'])
# set(['restant', 'straten', 'starten'])
# set(['dakvloer', 'loverdak'])
# set(['bronwater', 'waterbron'])
# set(['anorak', 'orkaan'])
# set(['fertiel', 'fiertel'])
# set(['geelbruin', 'bruingeel'])
# set(['tuinkers', 'nierstuk', 'kruisnet', 'struiken'])
# set(['loc', 'col'])
# set(['sets', 'ests'])
# set(['inbakken', 'kinnebak'])
# set(['ereprijs', 'perserij'])
# set(['troepentransport', 'transporttroepen'])
# set(['laks', 'klas', 'slak'])
# set(['verslagweek', 'weekverslag'])
# set(['hees', 'hese'])
# set(['thee', 'heet'])
# set(['faas', 'asfa'])
# set(['redactieraad', 'reactiedraad'])
# set(['hele', 'heel'])
# set(['ntaal', 'alant'])
# set(['productmarkt', 'marktproduct'])
# set(['strompelig', 'gipsmortel'])
# set(['part', 'prat', 'trap'])
# set(['star', 'arts', 'rats', 'tras'])
# set(['stamtaal', 'taalstam'])
# set(['host', 'shot'])
# set(['berken', 'breken'])
# set(['dramafilm', 'filmdrama'])
# set(['gemeenschapsleven', 'levensgemeenschap'])
# set(['heraanplant', 'plantenhaar'])
# set(['organisatiedoel', 'doelorganisatie'])
# set(['tetra', 'tater'])
# set(['via', 'avi'])
# set(['donorzaad', 'zaaddonor'])
# set(['slagzee', 'zeeslag'])
# set(['certificeren', 'rectificeren'])
# set(['sterven', 'venster', 'streven'])
# set(['lokroep', 'oorklep', 'looprek'])
# set(['raspsel', 'plasser', 'slapers'])
# set(['houtgraveur', 'houtgravure'])
# set(['veterane', 'taveerne'])
# set(['tafelspel', 'speltafel'])
# set(['zuidtak', 'zakduit'])
# set(['sleet', 'steel', 'leest', 'leste', 'stele'])
# set(['skelter', 'kletser', 'strekel', 'treksel'])
# set(['vinkje', 'kijven'])
# set(['neut', 'tune'])
# set(['sneu', 'neus'])
# set(['kennismarkt', 'marktkennis'])
# set(['vanwaar', 'waarvan'])
# set(['sterken', 'streken'])
# set(['werklieden', 'welriekend'])
# set(['kervel', 'klever', 'krevel'])
# set(['sjilpen', 'spijlen', 'slijpen'])
# set(['bruinrood', 'roodbruin'])
# set(['masse', 'sesam', 'assem'])
# set(['musk', 'smuk'])
# set(['belastingzaak', 'zaakbelasting'])
# set(['zijnet', 'tenzij'])
# set(['elastomeer', 'telomerase'])
# set(['artiesterig', 'registratie'])
# set(['ivoren', 'invoer'])
# set(['koter', 'korte'])
# set(['ploert', 'portel'])
# set(['winterdek', 'kinderwet'])
# set(['kerstgala', 'klaagster', 'streklaag'])
# set(['levenden', 'vendelen'])
# set(['smoren', 'morsen'])
# set(['vergiet', 'veertig'])
# set(['reef', 'free'])
# set(['tekenen', 'ketenen'])
# set(['ongedacht', 'nachtgoed'])
# set(['jaarverlies', 'verliesjaar'])
# set(['spel', 'pels'])
# set(['ontmenselijken', 'steenkolenmijn'])
# set(['droom', 'moord'])
# set(['toonkamer', 'atoomkern'])
# set(['inlegger', 'legering', 'regeling'])
# set(['deegsoort', 'gestoorde'])
# set(['lesavond', 'avondles'])
# set(['tuimeling', 'muiteling'])
# set(['kleien', 'kielen', 'kleine', 'keilen'])
# set(['poep', 'pope'])
# set(['rijdek', 'dijker'])
# set(['dijken', 'kindje'])
# set(['verliezen', 'verzeilen'])
# set(['porder', 'dorper'])
# set(['dorpel', 'polder'])
# set(['frutsel', 'slufter'])
# set(['wonderland', 'ronddwalen'])
# set(['uilskop', 'luiskop'])
# set(['gearmd', 'gedram'])
# set(['postbus', 'stopbus', 'busstop'])
# set(['onbewust', 'nestbouw'])
# set(['karet', 'raket', 'kater'])
# set(['karen', 'anker', 'raken'])
# set(['vierdubbel', 'dubbelvier'])
# set(['onbedekt', 'betondek'])
# set(['klapbes', 'bakspel'])
# set(['gloeien', 'legioen'])
# set(['stroomimport', 'importstroom'])
# set(['nodig', 'godin', 'dingo'])
# set(['eenling', 'engelin', 'lenigen'])
# set(['smartelijk', 'stijlkamer', 'kamerlijst'])
# set(['plandeel', 'deelplan'])
# set(['deens', 'snede', 'sneed'])
# set(['pakkerd', 'kerkpad'])
# set(['langspriet', 'sparteling'])
# set(['stilte', 'titels', 'stilet'])
# set(['karten', 'katern', 'tanker'])
# set(['langoer', 'organel'])
# set(['schier', 'riches'])
# set(['onderzoeksafdeling', 'afdelingsonderzoek'])
# set(['kralen', 'klaren'])
# set(['hoornsignaal', 'signaalhoorn'])
# set(['ntimeerde', 'mediteren'])
# set(['tonner', 'tornen', 'tronen'])
# set(['orkest', 'stoker', 'trekos', 'koster', 'korset'])
# set(['pompzwengel', 'zwengelpomp'])
# set(['caisson', 'incasso'])
# set(['slavenkust', 'tussenvlak'])
# set(['geiten', 'gieten'])
# set(['vlezen', 'zelven'])
# set(['staartlicht', 'lichtstraat'])
# set(['misjna', 'ijsman'])
# set(['veel', 'vele', 'leve'])
# set(['sekte', 'skeet', 'steek'])
# set(['liederen', 'elideren', 'riedelen'])
# set(['sverbouw', 'versbouw'])
# set(['su', 'us'])
# set(['denvat', 'advent'])
# set(['lijnen', 'nelijn'])
# set(['dokteren', 'donkerte'])
# set(['raadplaat', 'aardplaat'])
# set(['meelezer', 'zeemleer'])
# set(['rommelig', 'lommerig'])
# set(['blokker', 'brokkel'])
# set(['rapportage', 'praatgroep'])
# set(['genezen', 'zegenen'])
# set(['orgelpijp', 'pijporgel'])
# set(['kaartsysteem', 'systeemkaart'])
# set(['voordelig', 'volgroeid'])
# set(['multipel', 'multiple'])
# set(['spiernaakt', 'kaarsenpit'])
# set(['bakvis', 'visbak'])
# set(['stoelkussen', 'kussenstoel'])
# set(['ontwortelen', 'wortelnoten'])
# set(['res', 'ser', 'ers'])
# set(['laagveen', 'veenlaag'])
# set(['stopvlucht', 'postvlucht'])
# set(['epileren', 'pelerine'])
# set(['naken', 'kanen'])
# set(['septiem', 'septime'])
# set(['lambel', 'leblam'])
# set(['resem', 'smeer', 'meers'])
# set(['toonaard', 'aardnoot'])
# set(['maximumstraf', 'strafmaximum'])
# set(['steeg', 'geest', 'geste'])
# set(['hernia', 'hierna'])
# set(['ouderhulp', 'hulpouder'])
# set(['rieten', 'nieter', 'tieren', 'tiener', 'intree'])
# set(['intrek', 'rinket'])
# set(['wakker', 'kwaker'])
# set(['renvooi', 'vernooi'])
# set(['inkomensoverdracht', 'overdrachtsinkomen'])
# set(['eremiet', 'temeier'])
# set(['dalweiden', 'weideland'])
# set(['toesluiten', 'uitstoelen'])
# set(['geleding', 'diggelen', 'ingelegd'])
# set(['ringvinger', 'vingerring'])
# set(['tevens', 'vesten', 'steven'])
# set(['gewerkt', 'trekweg'])
# set(['visaas', 'aasvis'])
# set(['reutelen', 'leuteren'])
# set(['kruk', 'kurk'])
# set(['eskimo', 'moseik'])
# set(['volksraad', 'volksaard'])
# set(['rune', 'urne', 'uren'])
# set(['ondeelbaar', 'roedelbaan'])
# set(['afsteker', 'trekfase'])
# set(['onderwijstaal', 'taalonderwijs'])
# set(['roverbende', 'bevorderen'])
# set(['martelpaal', 'mallepraat'])
# set(['tranen', 'tarnen'])
# set(['servicegarantie', 'garantieservice'])
# set(['blikconserven', 'conservenblik'])
# set(['geldtas', 'stageld'])
# set(['plaatstalen', 'platenatlas'])
# set(['slam', 'mals', 'smal'])
# set(['poetser', 'erepost'])
# set(['afploegen', 'afgelopen'])
# set(['poetsen', 'stoepen'])
# set(['boomkor', 'rookbom'])
# set(['weerzin', 'zwieren'])
# set(['mensenwerk', 'werkmensen'])
# set(['lichtrood', 'richtlood'])
# set(['dopingvrij', 'opdrijving'])
# set(['huisbel', 'belhuis'])
# set(['riks', 'kris'])
# set(['visconsumptie', 'consumptievis'])
# set(['veulen', 'leuven'])
# set(['opstormen', 'opstromen'])
# set(['fiber', 'brief'])
# set(['sepot', 'pesto', 'stoep', 'poste', 'poets'])
# set(['fusieplan', 'afsluipen'])
# set(['laag', 'gala', 'gaal'])
# set(['paar', 'raap', 'para'])
# set(['lievig', 'veilig'])
# set(['bister', 'britse'])
# set(['reisbus', 'busreis'])
# set(['arp', 'par', 'rap'])
# set(['tra', 'rat', 'art'])
# set(['ara', 'aar'])
# set(['kar', 'ark', 'rak'])
# set(['ram', 'arm'])
# set(['storen', 'nestor', 'rotsen', 'torsen'])
# set(['spaarder', 'persraad'])
# set(['tref', 'fret'])
# set(['koest', 'koets', 'koste'])
# set(['sik', 'ski'])
# set(['wetsaanpassing', 'aanpassingswet'])
# set(['rampvlucht', 'palmvrucht'])
# set(['puntkomma', 'kommapunt'])
# set(['kwarttoon', 'kwartnoot'])
# set(['slijp', 'spijl'])
# set(['slijp', 'spijl'])
# set(['rijkleed', 'deerlijk', 'redelijk', 'lijkrede'])
# set(['leerstijl', 'stijlleer'])
# set(['spionagenet', 'pensioengat'])
# set(['triode', 'editor'])
# set(['steentijd', 'etenstijd'])
# set(['opalen', 'oelpan'])
# set(['kamerorgel', 'orgelmaker'])
# set(['urbi', 'brui'])
# set(['brug', 'burg'])
# set(['tekenmunt', 'muntteken'])
# set(['kransje', 'sjanker'])
# set(['filtering', 'flinterig'])
# set(['notering', 'ontering'])
# set(['belial', 'labiel'])
# set(['sportstand', 'strandpost'])
# set(['veroordelen', 'doorleveren'])
# set(['pletsen', 'spleten', 'netspel', 'stelpen'])
# set(['slapie', 'paleis'])
# set(['tolvrij', 'vrijlot'])
# set(['onnet', 'tonen', 'nonet', 'noten'])
# set(['feniks', 'fiksen'])
# set(['arr', 'rra'])
# set(['aangorden', 'ondergaan'])
# set(['mist', 'mits'])
# set(['negrito', 'gierton'])
# set(['gipsen', 'gispen', 'gespin'])
# set(['roterij', 'rijtoer'])
# set(['geeloranje', 'oranjegeel'])
# set(['groenloop', 'groenpool', 'loongroep'])
# set(['wegstromen', 'wegstormen'])
# set(['kruip', 'pruik'])
# set(['kniepees', 'pekinees'])
# set(['tap', 'pat'])
# set(['aft', 'taf', 'fat'])
# set(['klapmuts', 'kamplust'])
# set(['abt', 'bat', 'atb', 'tab'])
# set(['lat', 'tal', 'alt'])
# set(['tam', 'atm', 'mat'])
# set(['moederklooster', 'kloostermoeder'])
# set(['broederij', 'boerderij'])
# set(['spe', 'esp'])
# set(['kwartje', 'jatwerk'])
# set(['huishuur', 'huurhuis'])
# set(['onderwijsvak', 'vakonderwijs'])
# set(['tenminste', 'sentiment'])
# set(['poenen', 'openen'])
# set(['doelman', 'omladen'])
# set(['opmaker', 'opkamer'])
# set(['eenling', 'engelin', 'lenigen'])
# set(['crash', 'schar'])
# set(['onverdacht', 'ondervacht'])
# set(['bedrijfsingenieur', 'ingenieursbedrijf'])
# set(['trad', 'dart'])
# set(['afbedelen', 'afbeelden'])
# set(['dansrepetitie', 'predestinatie'])
# set(['sepot', 'pesto', 'stoep', 'poste', 'poets'])
# set(['opgraven', 'opvragen'])
# set(['vergiet', 'veertig'])
# set(['wereldsysteem', 'systeemwereld'])
# set(['waterbak', 'baktarwe'])
# set(['beleidsonderzoek', 'onderzoeksbeleid'])
# set(['gisteren', 'nesterig'])
# set(['waterfontein', 'fonteinwater'])
# set(['veerloon', 'oneervol'])
# set(['bladkool', 'koolblad'])
# set(['betel', 'belet'])
# set(['verslepen', 'verspelen'])
# set(['trance', 'centra', 'carnet', 'nectar'])
# set(['droomstaat', 'datastroom'])
# set(['ghi', 'hig'])
# set(['erving', 'vering', 'vinger', 'nervig'])
# set(['verkiezing', 'verzieking'])
# set(['duinvoet', 'uitdoven', 'tienvoud'])
# set(['dope', 'pedo'])
# set(['vervalsing', 'verslaving'])
# set(['gokken', 'geknok'])
# set(['jaarclub', 'clubjaar'])
# set(['kalkoen', 'koelkan'])
# set(['ebo', 'beo', 'boe'])
# set(['bankrente', 'rentebank'])
# set(['oliepit', 'politie'])
# set(['rondegang', 'ondergang'])
# set(['klare', 'rakel'])
# set(['zolen', 'lozen'])
# set(['armoedig', 'ideogram'])
# set(['knijpen', 'nekpijn'])
# set(['bloedeigen', 'onbegeleid'])
# set(['tapisserie', 'patisserie'])
# set(['aks', 'kas', 'sak', 'ska'])
# set(['mistlicht', 'lichtmist'])
# set(['lonk', 'knol'])
# set(['knop', 'ponk'])
# set(['marktniche', 'nichemarkt'])
# set(['kont', 'knot'])
# set(['rommelig', 'lommerig'])
# set(['krats', 'strak', 'karst'])
# set(['leader', 'dealer', 'alrede'])
# set(['stopdatum', 'postdatum'])
# set(['heerban', 'beharen'])
# set(['aceton', 'coaten'])
# set(['ie', 'ei'])
# set(['tarweprijs', 'waterprijs'])
# set(['winnaar', 'nirwana'])
# set(['bladsla', 'slablad'])
# set(['trekkar', 'kerkrat'])
# set(['rotskruiper', 'ruiterkorps'])
# set(['et', 'te'])
# set(['geweerkamer', 'geweermaker'])
# set(['re', 'er'])
# set(['nippel', 'neppil', 'lippen'])
